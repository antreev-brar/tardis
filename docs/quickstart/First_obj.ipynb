# %%
from tardis import run_tardis
from tardis.io.atom_data.util import download_atom_data
# Out:
# /Users/antreevsinghbrar/opt/anaconda3/envs/tardis/lib/python3.7/importlib/_bootstrap.py:219: QAWarning: pyne.data is not yet QA compliant.
#   return f(*args, **kwds)

# %%
# the data is automatically downloaded
download_atom_data('kurucz_cd23_chianti_H_He')
# Out:
# [tardis.io.atom_data.atom_web_download][INFO   ]  Downloading atomic data from https://media.githubusercontent.com/media/tardis-sn/tardis-refdata/master/atom_data/kurucz_cd23_chianti_H_He.h5 to /Users/antreevsinghbrar/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (atom_web_download.py:49)

# %%
sim = run_tardis('first_obj_yml.yml')
# Out:
# [tardis.plasma.standard_plasmas][INFO   ]  Reading Atomic Data from kurucz_cd23_chianti_H_He.h5 (standard_plasmas.py:87)
# [tardis.io.atom_data.util][INFO   ]  Atom Data kurucz_cd23_chianti_H_He.h5 not found in local path. Exists in TARDIS Data repo /Users/antreevsinghbrar/Downloads/tardis-data/kurucz_cd23_chianti_H_He.h5 (util.py:35)
# [py.warnings         ][WARNING]  /Users/antreevsinghbrar/opt/anaconda3/envs/tardis/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3427: PerformanceWarning: indexing past lexsort depth may impact performance.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#  (warnings.py:110)
# [tardis.io.atom_data.base][INFO   ]  Read Atom Data with UUID=6f7b09e887a311e7a06b246e96350010 and MD5=864f1753714343c41f99cb065710cace. (base.py:172)
# [tardis.io.atom_data.base][INFO   ]  Non provided atomic data: synpp_refs, photoionization_data (base.py:178)
# [tardis.simulation.base][INFO   ]  Starting iteration 1/20 (base.py:326)
# [py.warnings         ][WARNING]  /Users/antreevsinghbrar/opt/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 6.62478e+42 erg / s Luminosity absorbed = 3.84126e+42 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:450)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	        t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      7000.0  10736.379069  0.339927  0.680243
#
#  (base.py:436)
# [tardis.simulation.base][INFO   ]  t_inner 10982.397 K -- next t_inner 13887.240 K (base.py:439)
# [tardis.simulation.base][INFO   ]  Starting iteration 2/20 (base.py:326)
# [py.warnings         ][WARNING]  /Users/antreevsinghbrar/opt/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 1.19106e+43 erg / s Luminosity absorbed = 1.46989e+43 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:450)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad   next_t_rad         w    next_w
# 	Shell
# 	0      10736.379069  13503.64187  0.680243  0.691122
#
#  (base.py:436)
# [tardis.simulation.base][INFO   ]  t_inner 13887.240 K -- next t_inner 13096.469 K (base.py:439)
# [tardis.simulation.base][INFO   ]  Starting iteration 3/20 (base.py:326)
# [py.warnings         ][WARNING]  /Users/antreevsinghbrar/opt/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 8.51330e+42 erg / s Luminosity absorbed = 1.24937e+43 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:450)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	             t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      13503.64187  13172.183888  0.691122  0.615574
#
#  (base.py:436)
# [tardis.simulation.base][INFO   ]  t_inner 13096.469 K -- next t_inner 14608.647 K (base.py:439)
# [tardis.simulation.base][INFO   ]  Starting iteration 4/20 (base.py:326)
# [py.warnings         ][WARNING]  /Users/antreevsinghbrar/opt/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 1.31425e+43 erg / s Luminosity absorbed = 1.93815e+43 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:450)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad   next_t_rad         w    next_w
# 	Shell
# 	0      13172.183888  14398.98073  0.615574  0.662276
#
#  (base.py:436)
# [tardis.simulation.base][INFO   ]  t_inner 14608.647 K -- next t_inner 13115.211 K (base.py:439)
# [tardis.simulation.base][INFO   ]  Starting iteration 5/20 (base.py:326)
# [py.warnings         ][WARNING]  /Users/antreevsinghbrar/opt/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 8.52374e+42 erg / s Luminosity absorbed = 1.26019e+43 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:450)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	             t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      14398.98073  13275.948568  0.662276  0.596637
#
#  (base.py:436)
# [tardis.simulation.base][INFO   ]  t_inner 13115.211 K -- next t_inner 14620.587 K (base.py:439)
# [tardis.simulation.base][INFO   ]  Starting iteration 6/20 (base.py:326)
# [py.warnings         ][WARNING]  /Users/antreevsinghbrar/opt/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 1.30584e+43 erg / s Luminosity absorbed = 1.95640e+43 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:450)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad   next_t_rad         w    next_w
# 	Shell
# 	0      13275.948568  14474.40481  0.596637  0.649606
#
#  (base.py:436)
# [tardis.simulation.base][INFO   ]  t_inner 14620.587 K -- next t_inner 13168.147 K (base.py:439)
# [tardis.simulation.base][INFO   ]  Starting iteration 7/20 (base.py:326)
# [py.warnings         ][WARNING]  /Users/antreevsinghbrar/opt/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 8.72025e+42 erg / s Luminosity absorbed = 1.27520e+43 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:450)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	             t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      14474.40481  13416.843875  0.649606  0.577986
#
#  (base.py:436)
# [tardis.simulation.base][INFO   ]  t_inner 13168.147 K -- next t_inner 14513.256 K (base.py:439)
# [tardis.simulation.base][INFO   ]  Starting iteration 8/20 (base.py:326)
# [py.warnings         ][WARNING]  /Users/antreevsinghbrar/opt/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 1.28019e+43 erg / s Luminosity absorbed = 1.88759e+43 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:450)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      13416.843875  14374.043491  0.577986  0.653941
#
#  (base.py:436)
# [tardis.simulation.base][INFO   ]  t_inner 14513.256 K -- next t_inner 13201.778 K (base.py:439)
# [tardis.simulation.base][INFO   ]  Starting iteration 9/20 (base.py:326)
# [py.warnings         ][WARNING]  /Users/antreevsinghbrar/opt/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 8.62006e+42 erg / s Luminosity absorbed = 1.30651e+43 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:450)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad    next_t_rad         w   next_w
# 	Shell
# 	0      14374.043491  13421.730364  0.653941  0.58994
#
#  (base.py:436)
# [tardis.simulation.base][INFO   ]  t_inner 13201.778 K -- next t_inner 14634.637 K (base.py:439)
# [tardis.simulation.base][INFO   ]  Starting iteration 10/20 (base.py:326)
# [py.warnings         ][WARNING]  /Users/antreevsinghbrar/opt/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 1.31616e+43 erg / s Luminosity absorbed = 1.95890e+43 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:450)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad    next_t_rad        w    next_w
# 	Shell
# 	0      13421.730364  14425.665323  0.58994  0.664781
#
#  (base.py:436)
# [tardis.simulation.base][INFO   ]  t_inner 14634.637 K -- next t_inner 13128.996 K (base.py:439)
# [tardis.simulation.base][INFO   ]  Starting iteration 11/20 (base.py:326)
# [py.warnings         ][WARNING]  /Users/antreevsinghbrar/opt/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 8.65809e+42 erg / s Luminosity absorbed = 1.25610e+43 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:450)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      14425.665323  13300.024854  0.664781  0.596272
#
#  (base.py:436)
# [tardis.simulation.base][INFO   ]  t_inner 13128.996 K -- next t_inner 14521.952 K (base.py:439)
# [tardis.simulation.base][INFO   ]  Starting iteration 12/20 (base.py:326)
# [py.warnings         ][WARNING]  /Users/antreevsinghbrar/opt/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 1.26703e+43 erg / s Luminosity absorbed = 1.90852e+43 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:450)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      13300.024854  14395.861413  0.596272  0.648185
#
#  (base.py:436)
# [tardis.simulation.base][INFO   ]  t_inner 14521.952 K -- next t_inner 13278.117 K (base.py:439)
# [tardis.simulation.base][INFO   ]  Starting iteration 13/20 (base.py:326)
# [py.warnings         ][WARNING]  /Users/antreevsinghbrar/opt/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 8.98917e+42 erg / s Luminosity absorbed = 1.32092e+43 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:450)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      14395.861413  13476.220681  0.648185  0.587772
#
#  (base.py:436)
# [tardis.simulation.base][INFO   ]  t_inner 13278.117 K -- next t_inner 14413.891 K (base.py:439)
# [tardis.simulation.base][INFO   ]  Starting iteration 14/20 (base.py:326)
# [py.warnings         ][WARNING]  /Users/antreevsinghbrar/opt/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 1.22961e+43 erg / s Luminosity absorbed = 1.85245e+43 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:450)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      13476.220681  14370.932309  0.587772  0.633785
#
#  (base.py:436)
# [tardis.simulation.base][INFO   ]  t_inner 14413.891 K -- next t_inner 13378.348 K (base.py:439)
# [tardis.simulation.base][INFO   ]  Starting iteration 15/20 (base.py:326)
# [py.warnings         ][WARNING]  /Users/antreevsinghbrar/opt/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 9.36500e+42 erg / s Luminosity absorbed = 1.35140e+43 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:450)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      14370.932309  13541.537137  0.633785  0.598547
#
#  (base.py:436)
# [tardis.simulation.base][INFO   ]  t_inner 13378.348 K -- next t_inner 14228.305 K (base.py:439)
# [tardis.simulation.base][INFO   ]  Starting iteration 16/20 (base.py:326)
# [py.warnings         ][WARNING]  /Users/antreevsinghbrar/opt/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 1.18092e+43 erg / s Luminosity absorbed = 1.74533e+43 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:450)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      13541.537137  14262.321637  0.598547  0.623014
#
#  (base.py:436)
# [tardis.simulation.base][INFO   ]  t_inner 14228.305 K -- next t_inner 13475.590 K (base.py:439)
# [tardis.simulation.base][INFO   ]  Starting iteration 17/20 (base.py:326)
# [py.warnings         ][WARNING]  /Users/antreevsinghbrar/opt/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 9.51959e+42 erg / s Luminosity absorbed = 1.40313e+43 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:450)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      14262.321637  13619.115723  0.623014  0.592296
#
#  (base.py:436)
# [tardis.simulation.base][INFO   ]  t_inner 13475.590 K -- next t_inner 14214.887 K (base.py:439)
# [tardis.simulation.base][INFO   ]  Starting iteration 18/20 (base.py:326)
# [py.warnings         ][WARNING]  /Users/antreevsinghbrar/opt/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 1.17731e+43 erg / s Luminosity absorbed = 1.73772e+43 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:450)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      13619.115723  14126.745884  0.592296  0.645807
#
#  (base.py:436)
# [tardis.simulation.base][INFO   ]  t_inner 14214.887 K -- next t_inner 13483.486 K (base.py:439)
# [tardis.simulation.base][INFO   ]  Starting iteration 19/20 (base.py:326)
# [py.warnings         ][WARNING]  /Users/antreevsinghbrar/opt/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 9.54013e+42 erg / s Luminosity absorbed = 1.40632e+43 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:450)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      14126.745884  13627.479538  0.645807  0.595193
#
#  (base.py:436)
# [tardis.simulation.base][INFO   ]  t_inner 13483.486 K -- next t_inner 14207.892 K (base.py:439)
# [tardis.simulation.base][INFO   ]  Starting iteration 20/20 (base.py:326)
# [py.warnings         ][WARNING]  /Users/antreevsinghbrar/opt/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 1.16409e+43 erg / s Luminosity absorbed = 1.74507e+43 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:450)
# [tardis.simulation.base][INFO   ]  Simulation finished in 20 iterations and took 11.88 s (base.py:384)

# %%
# %pylab inline
#if pandas is not already installed run this command
#!pip install pandas
import pandas 

figure(figsize=(10,6))
plotdf = pandas.DataFrame(sim.model._abundance.T) 
elements=plotdf.columns.values
plotdf['velocity'] = sim.model.v_inner.cgs

print(sim.model._abundance)
#print(type(sim.model._abundance.__dict__))
#print(type(elements))
#print(plotdf.columns.values)

#numpy.delete(y,[-1],None)
print(elements[:])
plotdf.plot('velocity',elements[:],kind = 'line',figsize=(10,6),grid = True , title="Abundance vs velocity")
ylabel('Abundance')
xlabel("Velocity(Inner shell boundary)")
# Out:
# Populating the interactive namespace from numpy and matplotlib
#                   0     1    2
# atomic_number
# 1              0.00  0.40  0.5
# 2              0.99  0.58  0.4
# 14             0.01  0.02  0.1
# [ 1  2 14]
# Text(0.5, 0, 'Velocity(Inner shell boundary)')
